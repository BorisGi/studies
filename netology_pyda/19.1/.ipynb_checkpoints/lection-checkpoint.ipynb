# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
woman_shoes = pd.read_csv('Datafiniti_Womens_Shoes.csv')
woman_shoes.head(5)
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# 0             Shoes  Silver,Cream Watercolor Floral                       NaN
# 1             Shoes                            Grey                       NaN
# 2             Shoes                            Grey                       NaN
# 3       Shoes,Shoes                           Black  6.0 in x 6.0 in x 1.0 in
# 4             Shoes                            Grey  6.0 in x 6.0 in x 1.0 in
#
#             ean  ...   prices.merchant prices.offer prices.returnPolicy  \
# 0           NaN  ...     Overstock.com          NaN                 NaN
# 1  3.397705e+10  ...       Walmart.com          NaN                 NaN
# 2  3.397705e+10  ...  Slippers Dot Com          NaN                 NaN
# 3  3.397705e+10  ...  Slippers Dot Com          NaN                 NaN
# 4  3.397705e+10  ...       Walmart.com          NaN                 NaN
#
#   prices.shipping prices.size  \
# 0             NaN           S
# 1        Standard           6
# 2           Value           6
# 3           Value           6
# 4       Expedited           6
#
#                                    prices.sourceURLs  \
# 0  https://www.overstock.com/Clothing-Shoes/Women...
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 2  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 3  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# 4  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
#
#                                                sizes  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                         10,7,6,9,8
# 2                                         10,7,6,9,8
# 3                                         10,7,6,9,8
# 4                                         10,7,6,9,8
#
#                                           sourceURLs           upc weight
# 0  https://www.walmart.com/ip/Naturalizer-Danya-W...  017136472311    NaN
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 2  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 3  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045903    NaN
# 4  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045958    NaN
#
# [5 rows x 34 columns]

# %%
woman_shoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 34 columns):
# id                     10000 non-null object
# dateAdded              10000 non-null object
# dateUpdated            10000 non-null object
# asins                  3 non-null object
# brand                  10000 non-null object
# categories             10000 non-null object
# primaryCategories      10000 non-null object
# colors                 2631 non-null object
# dimension              117 non-null object
# ean                    671 non-null float64
# imageURLs              10000 non-null object
# keys                   10000 non-null object
# manufacturer           527 non-null object
# manufacturerNumber     2482 non-null object
# name                   10000 non-null object
# prices.amountMax       10000 non-null float64
# prices.amountMin       10000 non-null float64
# prices.availability    434 non-null object
# prices.color           10000 non-null object
# prices.condition       438 non-null object
# prices.currency        10000 non-null object
# prices.dateAdded       9223 non-null object
# prices.dateSeen        10000 non-null object
# prices.isSale          10000 non-null bool
# prices.merchant        435 non-null object
# prices.offer           121 non-null object
# prices.returnPolicy    0 non-null float64
# prices.shipping        412 non-null object
# prices.size            10000 non-null object
# prices.sourceURLs      10000 non-null object
# sizes                  10000 non-null object
# sourceURLs             10000 non-null object
# upc                    9640 non-null object
# weight                 299 non-null object
# dtypes: bool(1), float64(4), object(29)
# memory usage: 2.5+ MB

# %%
columns = ['dateAdded', 'brand', 'colors', 'name', 'prices.amountMax',
           'prices.amountMin', 'prices.availability', 'prices.size']

# %%
woman_shoes['primaryCategories'].value_counts()
# Out:
# Shoes          9361
# Shoes,Shoes     639
# Name: primaryCategories, dtype: int64

# %%
woman_shoes['manufacturber'].value_counts(dropna=False)
# Out:
# NaN                      9473
# Dr. Scholl's              253
# Brinley Co.               139
# Easy Street                48
# Brinley Co                 16
# Spring Footwear            14
# Eastland Shoe              13
# ASICS                      11
# Reliable of Milwuakee       7
# Fila                        7
# Reliable of Milwaukee       5
# Lugz                        4
# Muk Luks                    3
# Riverberry                  1
# S-1944-red-6                1
# Soft Ones                   1
# Silver Lilly                1
# ELLIE SHOES                 1
# Journee Collection          1
# Sloggers                    1
# Name: manufacturer, dtype: int64

# %%
woman_shoes['name'].value_counts()
# Out:
# Nike Flex Experience 6 Women's Running Shoes             185
# LifeStride Lively Women's High Heels                     157
# Dr. Scholl's Madison Women's Sneakers                    144
# Simply Vera Vera Wang Women's All-Over Stretch Heels     121
# Dr. Scholl's Jorie Women's Ankle Boots                   109
#                                                         ...
# Faded Glory Women's  Walk Moccasin Shoe                    1
# NYLA Bessie Women's Chunky-Heel Sandals                    1
# Nike Zoom Janoski Slip-On Skate Shoe - Women's             1
# Saucony Peregrine 7 Ice+ Trail Running Shoe - Women's      1
# Dr. Scholl's Women's Freestyle                             1
# Name: name, Length: 649, dtype: int64

# %%
woman_shoes['prices.availability'].value_counts(dropna=False)
# Out:
# NaN             9566
# TRUE             353
# In Stock          53
# Out Of Stock      28
# Name: prices.availability, dtype: int64

# %%
woman_shoes['prices.isSale'].value_counts(dropna=False)
# Out:
# False    9830
# True      170
# Name: prices.isSale, dtype: int64

# %%
woman_shoes['prices.size'].value_counts(dropna=False)
# Out:
# 6                      435
# 6.5 MED                415
# 8 MED                  411
# 7 MED                  408
# 8                      408
#                       ...
# Mens 7.0/Womens 8.5      1
# Mens 6.0/Womens 7.5      1
# 4                        1
# Mens 4.5/Womens 6.0      1
# 41 WIDE                  1
# Name: prices.size, Length: 83, dtype: int64

# %%
woman_shoes = woman_shoes[columns]
woman_shoes.head(5)
# Out:
#               dateAdded        brand                          colors  \
# 0  2015-05-04T12:13:08Z  Naturalizer  Silver,Cream Watercolor Floral
# 1  2017-01-27T01:23:39Z     MUK LUKS                            Grey
# 2  2017-01-27T01:23:39Z     MUK LUKS                            Grey
# 3  2017-01-27T01:25:56Z     MUK LUKS                           Black
# 4  2017-01-27T01:25:56Z     MUK LUKS                            Grey
#
#                                                 name  prices.amountMax  \
# 0  Naturalizer Danya Women N/S Open Toe Synthetic...             55.99
# 1                MUK LUKS Womens Jane Suede Moccasin             47.00
# 2                MUK LUKS Womens Jane Suede Moccasin             35.25
# 3           MUK LUKS Womens Dawn Suede Scuff Slipper             24.75
# 4           MUK LUKS Womens Dawn Suede Scuff Slipper             33.00
#
#    prices.amountMin prices.availability prices.size
# 0             55.99                 NaN           S
# 1             35.25            In Stock           6
# 2             35.25            In Stock           6
# 3             24.75            In Stock           6
# 4             30.39            In Stock           6

# %%
plt.figure(figsize=(10, 12))
sns.boxplot(x='prices.amountMax', y='brand', data=woman_shoes)

# %%
woman_shoes['brand'].value_counts()
# Out:
# journee collection                2182
# lifestride                        1457
# a2 by aerosoles                    670
# easy street                        556
# style charles by charles david     478
#                                   ...
# forever collectibles                 1
# Genuine Dickies                      1
# Keds                                 1
# Danskin Now                          1
# nyla                                 1
# Name: brand, Length: 129, dtype: int64

# %%
brand_counts = woman_shoes['brand'].value_counts()
brand_counts[brand_counts > 100]
# Out:
# journee collection                2182
# lifestride                        1457
# a2 by aerosoles                    670
# easy street                        556
# style charles by charles david     478
# so                                 422
# dr. scholls                        337
# croft barrow                       315
# nike                               285
# new balance                        255
# sonoma goods for life              229
# skechers                           185
# apt. 9                             183
# Nike                               179
# simply vera vera wang              164
# SKECHERS                           151
# candies                            144
# Lifestride                         136
# ryka                               129
# asics                              111
# naturalsoul by naturalizer         107
# Name: brand, dtype: int64

# %%
woman_shoes['brand'] = woman_shoes['brand'].str.lower()

# %%
brand_counts = woman_shoes['brand'].str.lower().value_counts()
brand_counts = brand_counts[brand_counts > 100]
brand_counts
# Out:
# journee collection                2182
# lifestride                        1593
# a2 by aerosoles                    670
# easy street                        585
# style charles by charles david     478
# nike                               464
# so                                 422
# dr. scholls                        337
# skechers                           336
# croft barrow                       315
# new balance                        267
# sonoma goods for life              229
# apt. 9                             183
# simply vera vera wang              164
# ryka                               147
# candies                            144
# asics                              130
# naturalsoul by naturalizer         107
# Name: brand, dtype: int64

# %%
woman_shoes.shape
# Out:
# (10000, 8)

# %%
woman_shoes = woman_shoes[woman_shoes['brand'].isin(brand_counts.index)]
woman_shoes.head(5)
# Out:
#                dateAdded     brand       colors  \
# 27  2017-11-10T19:33:31Z  skechers        Black
# 28  2017-11-10T19:33:31Z  skechers        Black
# 29  2017-07-25T04:36:20Z  skechers        Black
# 30  2017-11-05T03:20:19Z  skechers  Taupe,White
# 31  2017-11-05T03:20:19Z  skechers  Taupe,White
#
#                                                  name  prices.amountMax  \
# 27  Skechers Women's Skech-Air Lingle Black Memory...             85.00
# 28  Skechers Women's Skech-Air Lingle Black Memory...             85.00
# 29  76580 W Wide Width Black Skechers Shoe New Wom...             75.00
# 30  Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...             49.99
# 31  Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...             49.99
#
#     prices.amountMin prices.availability prices.size
# 27             85.00                 NaN           9
# 28             85.00                 NaN           8
# 29             75.00                 NaN           7
# 30             44.99                 NaN           8
# 31             49.99                 NaN           9

# %%
woman_shoes.shape
# Out:
# (8753, 8)

# %%
woman_shoes['avg_price'] = (woman_shoes['prices.amountMax'] + woman_shoes['prices.amountMin']) / 2
woman_shoes.head(5)
# Out:
#                dateAdded     brand       colors  \
# 27  2017-11-10T19:33:31Z  skechers        Black
# 28  2017-11-10T19:33:31Z  skechers        Black
# 29  2017-07-25T04:36:20Z  skechers        Black
# 30  2017-11-05T03:20:19Z  skechers  Taupe,White
# 31  2017-11-05T03:20:19Z  skechers  Taupe,White
#
#                                                  name  prices.amountMax  \
# 27  Skechers Women's Skech-Air Lingle Black Memory...             85.00
# 28  Skechers Women's Skech-Air Lingle Black Memory...             85.00
# 29  76580 W Wide Width Black Skechers Shoe New Wom...             75.00
# 30  Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...             49.99
# 31  Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...             49.99
#
#     prices.amountMin prices.availability prices.size  avg_price
# 27             85.00                 NaN           9      85.00
# 28             85.00                 NaN           8      85.00
# 29             75.00                 NaN           7      75.00
# 30             44.99                 NaN           8      47.49
# 31             49.99                 NaN           9      49.99

# %%
plt.figure(figsize=(10, 12))
sns.boxplot(x='avg_price', y='brand', data=woman_shoes)

# %%
six_data = woman_shoes[woman_shoes['prices.size'] == '6']
six_med_data = woman_shoes[woman_shoes['prices.size'] == '6.5 MED']

# %%
six_data['avg_price'].hist()

# %%
six_med_data['avg_price'].hist()

# %%
from scipy.stats import shapiro

# %%
from scipy.stats import ttest_ind

print('Mean values:')
print('6 size: {}'.format(six_data['avg_price'].mean()))
print('6.5 MED size: {}'.format(six_med_data['avg_price'].mean()))
      
ttest, p_val = ttest_ind(six_data['avg_price'], six_med_data['avg_price'])

if p_val > 0.05:
    print('Нулевую гипотезу о равенстве средних отклонить не можем')
else:
    print('Нулевую гипотезу о равенстве средних отклонить можем')
# Out:
# Mean values:
# 6 size: 59.65434426229503
# 6.5 MED size: 58.07235142118909
# Нулевую гипотезу о равенстве средних отклонить не можем

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='avg_price', y='prices.size',
            data=woman_shoes[woman_shoes['prices.size'].isin(['6', '6.5 MED'])])

# %%
ryka_data = woman_shoes.query('brand == "ryka"')
asics_data = woman_shoes.query('brand == "asics"')
print('Mean values:')
print('Ryka: {}'.format(ryka_data['avg_price'].mean()))
print('Asics size: {}'.format(asics_data['avg_price'].mean()))
      
ttest, p_val = ttest_ind(ryka_data['avg_price'], asics_data['avg_price'])

if p_val > 0.05:
    print('Нулевую гипотезу о равенстве средних отклонить не можем')
else:
    print('Нулевую гипотезу о равенстве средних отклонить можем')
# Out:
# Mean values:
# Ryka: 65.06741496598639
# Asics size: 81.6150384615384
# Нулевую гипотезу о равенстве средних отклонить можем

# %%
plt.figure(figsize=(10, 12))
sns.boxplot(x='avg_price', y='brand',
            data=woman_shoes[woman_shoes['brand'].isin(['ryka', 'asics'])])

# %%
ryka_data = woman_shoes.query('brand == "ryka"')
nike_data = woman_shoes.query('brand == "nike"')
print('Mean values:')
print('Ryka: {}'.format(ryka_data['avg_price'].mean()))
print('Nike size: {}'.format(nike_data['avg_price'].mean()))
      
ttest, p_val = ttest_ind(ryka_data['avg_price'], nike_data['avg_price'])

if p_val > 0.05:
    print('Нулевую гипотезу о равенстве средних отклонить не можем')
else:
    print('Нулевую гипотезу о равенстве средних отклонить можем')
# Out:
# Mean values:
# Ryka: 65.06741496598639
# Nike size: 67.90452586206894
# Нулевую гипотезу о равенстве средних отклонить можем

# %%
plt.figure(figsize=(10, 12))
sns.boxplot(x='avg_price', y='brand',
            data=woman_shoes[woman_shoes['brand'].isin(['ryka', 'nike'])])

# %%
woman_shoes['year_added'] = woman_shoes['dateAdded'].str[:4].astype(int)
woman_shoes.head(5)
# Out:
#                dateAdded     brand       colors  \
# 27  2017-11-10T19:33:31Z  skechers        Black
# 28  2017-11-10T19:33:31Z  skechers        Black
# 29  2017-07-25T04:36:20Z  skechers        Black
# 30  2017-11-05T03:20:19Z  skechers  Taupe,White
# 31  2017-11-05T03:20:19Z  skechers  Taupe,White
#
#                                                  name  prices.amountMax  \
# 27  Skechers Women's Skech-Air Lingle Black Memory...             85.00
# 28  Skechers Women's Skech-Air Lingle Black Memory...             85.00
# 29  76580 W Wide Width Black Skechers Shoe New Wom...             75.00
# 30  Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...             49.99
# 31  Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...             49.99
#
#     prices.amountMin prices.availability prices.size  avg_price  year_added
# 27             85.00                 NaN           9      85.00        2017
# 28             85.00                 NaN           8      85.00        2017
# 29             75.00                 NaN           7      75.00        2017
# 30             44.99                 NaN           8      47.49        2017
# 31             49.99                 NaN           9      49.99        2017

# %%
woman_shoes['year_added'].value_counts()
# Out:
# 2017    8422
# 2018     232
# 2016      99
# Name: year_added, dtype: int64

# %%
plt.figure(figsize=(10, 12))
sns.boxplot(x='year_added', y='avg_price',
            data=woman_shoes.query('brand == "nike"'))

# %%
woman_shoes.query('brand == "nike"').pivot_table(index='name',
                                                 columns='year_added',
                                                 values='avg_price',
                                                 aggfunc='mean')
# Out:
# year_added                                               2017        2018
# name
# Nike Air Max Dynasty 2 Women's Running Shoes        80.750000         NaN
# Nike Air Precision Women's Basketball Shoes         70.000000         NaN
# Nike Air Zoom Pegasus 34 Running Shoe - Women's           NaN   96.205000
# Nike Air Zoom Structure 21 Running Shoe - Narro...        NaN  104.955000
# Nike CK Racer Women's Sneakers                      73.315909         NaN
# Nike City Trainer Shoe Women's Training Shoes       61.027353         NaN
# Nike Court Lite Women's Tennis Shoes                      NaN   62.214286
# Nike Flex Experience 6 Women's Running Shoes        60.236432         NaN
# Nike Free RN Running Shoe - Women's                       NaN   99.950000
# Nike Initiator Women's Running Shoes                52.372500         NaN
# Nike Kawa Slide Womens Style : 834588               28.673824         NaN
# Nike LunarEpic Low Flyknit 2 Running Shoe - Wom...        NaN  127.960000
# Nike LunarGlide 9 Running Shoe - Women's                  NaN  104.955000
# Nike SB Check Solarsoft Women's Skate Shoes         62.935000         NaN
# Nike Superflyte Women's Sneakers                    63.622500         NaN
# Nike Women's Air Zoom Winflo 4 Running Shoe Ant...  85.283125         NaN
# Nike Women's Lunar Apparent Running Shoe            77.495000         NaN
# Nike Zoom Janoski Slip-On Skate Shoe - Women's            NaN   61.835000
# Women's Nike In-Season 7 Training Shoe Black/Me...  69.471016         NaN

# %%
new_size_df = woman_shoes['prices.size'].str.extract(r'([0-9\.]+)? ?([A-Za-z]+)?')
new_size_df.columns = ['size', 'size_cat']
new_size_df.head(5)

woman_shoes = woman_shoes.merge(new_size_df, left_index=True, right_index=True)
woman_shoes.head(5)
# Out:
#                dateAdded     brand       colors  \
# 27  2017-11-10T19:33:31Z  skechers        Black
# 28  2017-11-10T19:33:31Z  skechers        Black
# 29  2017-07-25T04:36:20Z  skechers        Black
# 30  2017-11-05T03:20:19Z  skechers  Taupe,White
# 31  2017-11-05T03:20:19Z  skechers  Taupe,White
#
#                                                  name  prices.amountMax  \
# 27  Skechers Women's Skech-Air Lingle Black Memory...             85.00
# 28  Skechers Women's Skech-Air Lingle Black Memory...             85.00
# 29  76580 W Wide Width Black Skechers Shoe New Wom...             75.00
# 30  Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...             49.99
# 31  Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...             49.99
#
#     prices.amountMin prices.availability prices.size  avg_price  year_added  \
# 27             85.00                 NaN           9      85.00        2017
# 28             85.00                 NaN           8      85.00        2017
# 29             75.00                 NaN           7      75.00        2017
# 30             44.99                 NaN           8      47.49        2017
# 31             49.99                 NaN           9      49.99        2017
#
#    size size_cat
# 27    9      NaN
# 28    8      NaN
# 29    7      NaN
# 30    8      NaN
# 31    9      NaN

# %%
nike_size_pivot = woman_shoes.query('brand == "nike"').pivot_table(index='name',
                                                                   columns='size',
                                                                   values='avg_price',
                                                                   aggfunc='mean')
nike_size_pivot
# Out:
# size                                                        10       10.5  \
# name
# Nike Air Max Dynasty 2 Women's Running Shoes         79.687500  77.916667
# Nike Air Precision Women's Basketball Shoes                NaN        NaN
# Nike Air Zoom Pegasus 34 Running Shoe - Women's      96.205000        NaN
# Nike Air Zoom Structure 21 Running Shoe - Narro...         NaN        NaN
# Nike CK Racer Women's Sneakers                       70.996667        NaN
# Nike City Trainer Shoe Women's Training Shoes        65.000000        NaN
# Nike Court Lite Women's Tennis Shoes                 65.000000  55.250000
# Nike Flex Experience 6 Women's Running Shoes         60.956667  59.337059
# Nike Free RN Running Shoe - Women's                        NaN        NaN
# Nike Initiator Women's Running Shoes                       NaN        NaN
# Nike Kawa Slide Womens Style : 834588                27.495000        NaN
# Nike LunarEpic Low Flyknit 2 Running Shoe - Wom...  127.960000        NaN
# Nike LunarGlide 9 Running Shoe - Women's                   NaN        NaN
# Nike SB Check Solarsoft Women's Skate Shoes                NaN  65.000000
# Nike Superflyte Women's Sneakers                     61.872500        NaN
# Nike Women's Air Zoom Winflo 4 Running Shoe Ant...   85.498000  84.499000
# Nike Women's Lunar Apparent Running Shoe             77.495000        NaN
# Nike Zoom Janoski Slip-On Skate Shoe - Women's             NaN        NaN
# Women's Nike In-Season 7 Training Shoe Black/Me...   69.247000  66.499000
#
# size                                                       11         12  \
# name
# Nike Air Max Dynasty 2 Women's Running Shoes        77.916667  85.000000
# Nike Air Precision Women's Basketball Shoes               NaN        NaN
# Nike Air Zoom Pegasus 34 Running Shoe - Women's     96.205000        NaN
# Nike Air Zoom Structure 21 Running Shoe - Narro...        NaN        NaN
# Nike CK Racer Women's Sneakers                      80.000000        NaN
# Nike City Trainer Shoe Women's Training Shoes       56.875000  65.000000
# Nike Court Lite Women's Tennis Shoes                      NaN        NaN
# Nike Flex Experience 6 Women's Running Shoes        60.954412  60.396818
# Nike Free RN Running Shoe - Women's                 99.950000        NaN
# Nike Initiator Women's Running Shoes                55.000000        NaN
# Nike Kawa Slide Womens Style : 834588               28.330000  30.000000
# Nike LunarEpic Low Flyknit 2 Running Shoe - Wom...        NaN        NaN
# Nike LunarGlide 9 Running Shoe - Women's                  NaN        NaN
# Nike SB Check Solarsoft Women's Skate Shoes         60.500000        NaN
# Nike Superflyte Women's Sneakers                    62.495000        NaN
# Nike Women's Air Zoom Winflo 4 Running Shoe Ant...  86.523500        NaN
# Nike Women's Lunar Apparent Running Shoe                  NaN        NaN
# Nike Zoom Janoski Slip-On Skate Shoe - Women's            NaN        NaN
# Women's Nike In-Season 7 Training Shoe Black/Me...  68.373000        NaN
#
# size                                                        5        5.5  \
# name
# Nike Air Max Dynasty 2 Women's Running Shoes              NaN  85.000000
# Nike Air Precision Women's Basketball Shoes               NaN        NaN
# Nike Air Zoom Pegasus 34 Running Shoe - Women's           NaN        NaN
# Nike Air Zoom Structure 21 Running Shoe - Narro...        NaN        NaN
# Nike CK Racer Women's Sneakers                            NaN        NaN
# Nike City Trainer Shoe Women's Training Shoes             NaN        NaN
# Nike Court Lite Women's Tennis Shoes                      NaN        NaN
# Nike Flex Experience 6 Women's Running Shoes        60.087143  60.623333
# Nike Free RN Running Shoe - Women's                       NaN        NaN
# Nike Initiator Women's Running Shoes                55.000000        NaN
# Nike Kawa Slide Womens Style : 834588                     NaN        NaN
# Nike LunarEpic Low Flyknit 2 Running Shoe - Wom...        NaN        NaN
# Nike LunarGlide 9 Running Shoe - Women's                  NaN        NaN
# Nike SB Check Solarsoft Women's Skate Shoes               NaN        NaN
# Nike Superflyte Women's Sneakers                          NaN        NaN
# Nike Women's Air Zoom Winflo 4 Running Shoe Ant...  87.495000        NaN
# Nike Women's Lunar Apparent Running Shoe                  NaN  77.495000
# Nike Zoom Janoski Slip-On Skate Shoe - Women's            NaN        NaN
# Women's Nike In-Season 7 Training Shoe Black/Me...  67.968750  70.622000
#
# size                                                         6         6.5  \
# name
# Nike Air Max Dynasty 2 Women's Running Shoes         79.687500   76.500000
# Nike Air Precision Women's Basketball Shoes          70.000000         NaN
# Nike Air Zoom Pegasus 34 Running Shoe - Women's            NaN   96.205000
# Nike Air Zoom Structure 21 Running Shoe - Narro...         NaN  104.955000
# Nike CK Racer Women's Sneakers                       70.247500   80.000000
# Nike City Trainer Shoe Women's Training Shoes        56.875000   59.995000
# Nike Court Lite Women's Tennis Shoes                       NaN         NaN
# Nike Flex Experience 6 Women's Running Shoes         59.864643   61.204286
# Nike Free RN Running Shoe - Women's                        NaN         NaN
# Nike Initiator Women's Running Shoes                       NaN   52.495000
# Nike Kawa Slide Womens Style : 834588                28.747500         NaN
# Nike LunarEpic Low Flyknit 2 Running Shoe - Wom...         NaN         NaN
# Nike LunarGlide 9 Running Shoe - Women's            104.955000         NaN
# Nike SB Check Solarsoft Women's Skate Shoes                NaN         NaN
# Nike Superflyte Women's Sneakers                           NaN         NaN
# Nike Women's Air Zoom Winflo 4 Running Shoe Ant...   83.905000   81.311250
# Nike Women's Lunar Apparent Running Shoe             77.495000   77.495000
# Nike Zoom Janoski Slip-On Skate Shoe - Women's             NaN         NaN
# Women's Nike In-Season 7 Training Shoe Black/Me...   69.581667   71.123000
#
# size                                                         7        7.5  \
# name
# Nike Air Max Dynasty 2 Women's Running Shoes         81.458333  85.000000
# Nike Air Precision Women's Basketball Shoes                NaN        NaN
# Nike Air Zoom Pegasus 34 Running Shoe - Women's            NaN        NaN
# Nike Air Zoom Structure 21 Running Shoe - Narro...         NaN        NaN
# Nike CK Racer Women's Sneakers                             NaN        NaN
# Nike City Trainer Shoe Women's Training Shoes              NaN  58.435000
# Nike Court Lite Women's Tennis Shoes                 65.000000  65.000000
# Nike Flex Experience 6 Women's Running Shoes         59.720000  60.354615
# Nike Free RN Running Shoe - Women's                        NaN        NaN
# Nike Initiator Women's Running Shoes                       NaN        NaN
# Nike Kawa Slide Womens Style : 834588                28.330000        NaN
# Nike LunarEpic Low Flyknit 2 Running Shoe - Wom...         NaN        NaN
# Nike LunarGlide 9 Running Shoe - Women's            104.955000        NaN
# Nike SB Check Solarsoft Women's Skate Shoes          62.495000  59.995000
# Nike Superflyte Women's Sneakers                     62.495000  70.000000
# Nike Women's Air Zoom Winflo 4 Running Shoe Ant...   85.831111  90.000000
# Nike Women's Lunar Apparent Running Shoe             77.495000  77.495000
# Nike Zoom Janoski Slip-On Skate Shoe - Women's             NaN        NaN
# Women's Nike In-Season 7 Training Shoe Black/Me...   72.030000  69.194286
#
# size                                                        8        8.5  \
# name
# Nike Air Max Dynasty 2 Women's Running Shoes        79.687500  85.000000
# Nike Air Precision Women's Basketball Shoes               NaN  70.000000
# Nike Air Zoom Pegasus 34 Running Shoe - Women's     96.205000        NaN
# Nike Air Zoom Structure 21 Running Shoe - Narro...        NaN        NaN
# Nike CK Racer Women's Sneakers                      76.247500        NaN
# Nike City Trainer Shoe Women's Training Shoes       62.497500  65.000000
# Nike Court Lite Women's Tennis Shoes                55.250000  65.000000
# Nike Flex Experience 6 Women's Running Shoes        58.865313  60.043214
# Nike Free RN Running Shoe - Women's                       NaN  99.950000
# Nike Initiator Women's Running Shoes                55.000000  50.310000
# Nike Kawa Slide Womens Style : 834588               28.998000        NaN
# Nike LunarEpic Low Flyknit 2 Running Shoe - Wom...        NaN        NaN
# Nike LunarGlide 9 Running Shoe - Women's                  NaN        NaN
# Nike SB Check Solarsoft Women's Skate Shoes         62.495000  62.495000
# Nike Superflyte Women's Sneakers                    61.872500  61.872500
# Nike Women's Air Zoom Winflo 4 Running Shoe Ant...  85.712857  84.060000
# Nike Women's Lunar Apparent Running Shoe            77.495000  77.495000
# Nike Zoom Janoski Slip-On Skate Shoe - Women's            NaN        NaN
# Women's Nike In-Season 7 Training Shoe Black/Me...  70.248000  67.500000
#
# size                                                         9        9.5
# name
# Nike Air Max Dynasty 2 Women's Running Shoes         85.000000  80.750000
# Nike Air Precision Women's Basketball Shoes                NaN        NaN
# Nike Air Zoom Pegasus 34 Running Shoe - Women's      96.205000        NaN
# Nike Air Zoom Structure 21 Running Shoe - Narro...         NaN        NaN
# Nike CK Racer Women's Sneakers                             NaN  70.247500
# Nike City Trainer Shoe Women's Training Shoes        63.331667  59.215000
# Nike Court Lite Women's Tennis Shoes                 65.000000        NaN
# Nike Flex Experience 6 Women's Running Shoes         60.802857  60.207000
# Nike Free RN Running Shoe - Women's                        NaN        NaN
# Nike Initiator Women's Running Shoes                 52.495000  50.310000
# Nike Kawa Slide Womens Style : 834588                28.747500        NaN
# Nike LunarEpic Low Flyknit 2 Running Shoe - Wom...  127.960000        NaN
# Nike LunarGlide 9 Running Shoe - Women's                   NaN        NaN
# Nike SB Check Solarsoft Women's Skate Shoes                NaN  70.000000
# Nike Superflyte Women's Sneakers                           NaN  70.000000
# Nike Women's Air Zoom Winflo 4 Running Shoe Ant...   82.500000  85.935625
# Nike Women's Lunar Apparent Running Shoe                   NaN  77.495000
# Nike Zoom Janoski Slip-On Skate Shoe - Women's             NaN  61.835000
# Women's Nike In-Season 7 Training Shoe Black/Me...   71.248571  69.061250

# %%
nike_size_pivot.median(axis=1)
# Out:
# name
# Nike Air Max Dynasty 2 Women's Running Shoes                                            80.750000
# Nike Air Precision Women's Basketball Shoes                                             70.000000
# Nike Air Zoom Pegasus 34 Running Shoe - Women's                                         96.205000
# Nike Air Zoom Structure 21 Running Shoe - Narrow - Women's                             104.955000
# Nike CK Racer Women's Sneakers                                                          73.622083
# Nike City Trainer Shoe Women's Training Shoes                                           61.246250
# Nike Court Lite Women's Tennis Shoes                                                    65.000000
# Nike Flex Experience 6 Women's Running Shoes                                            60.280808
# Nike Free RN Running Shoe - Women's                                                     99.950000
# Nike Initiator Women's Running Shoes                                                    52.495000
# Nike Kawa Slide Womens Style : 834588                                                   28.747500
# Nike LunarEpic Low Flyknit 2 Running Shoe - Women's                                    127.960000
# Nike LunarGlide 9 Running Shoe - Women's                                               104.955000
# Nike SB Check Solarsoft Women's Skate Shoes                                             62.495000
# Nike Superflyte Women's Sneakers                                                        62.495000
# Nike Women's Air Zoom Winflo 4 Running Shoe Anthracite/Dark Grey-Black 10               85.605429
# Nike Women's Lunar Apparent Running Shoe                                                77.495000
# Nike Zoom Janoski Slip-On Skate Shoe - Women's                                          61.835000
# Women's Nike In-Season 7 Training Shoe Black/Metallic Silver/Anthracite Size 8 M US     69.247000
# dtype: float64

# %%
m = nike_size_pivot.median(axis=1)
for i, col in enumerate(nike_size_pivot):
    nike_size_pivot.iloc[:, i] = nike_size_pivot.iloc[:, i].fillna(m)

# %%
nike_size_pivot.transpose()
# Out:
# name  Nike Air Max Dynasty 2 Women's Running Shoes  \
# size
# 10                                       79.687500
# 10.5                                     77.916667
# 11                                       77.916667
# 12                                       85.000000
# 5                                        80.750000
# 5.5                                      85.000000
# 6                                        79.687500
# 6.5                                      76.500000
# 7                                        81.458333
# 7.5                                      85.000000
# 8                                        79.687500
# 8.5                                      85.000000
# 9                                        85.000000
# 9.5                                      80.750000
#
# name  Nike Air Precision Women's Basketball Shoes  \
# size
# 10                                           70.0
# 10.5                                         70.0
# 11                                           70.0
# 12                                           70.0
# 5                                            70.0
# 5.5                                          70.0
# 6                                            70.0
# 6.5                                          70.0
# 7                                            70.0
# 7.5                                          70.0
# 8                                            70.0
# 8.5                                          70.0
# 9                                            70.0
# 9.5                                          70.0
#
# name  Nike Air Zoom Pegasus 34 Running Shoe - Women's  \
# size
# 10                                             96.205
# 10.5                                           96.205
# 11                                             96.205
# 12                                             96.205
# 5                                              96.205
# 5.5                                            96.205
# 6                                              96.205
# 6.5                                            96.205
# 7                                              96.205
# 7.5                                            96.205
# 8                                              96.205
# 8.5                                            96.205
# 9                                              96.205
# 9.5                                            96.205
#
# name  Nike Air Zoom Structure 21 Running Shoe - Narrow - Women's  \
# size
# 10                                              104.955
# 10.5                                            104.955
# 11                                              104.955
# 12                                              104.955
# 5                                               104.955
# 5.5                                             104.955
# 6                                               104.955
# 6.5                                             104.955
# 7                                               104.955
# 7.5                                             104.955
# 8                                               104.955
# 8.5                                             104.955
# 9                                               104.955
# 9.5                                             104.955
#
# name  Nike CK Racer Women's Sneakers  \
# size
# 10                         70.996667
# 10.5                       73.622083
# 11                         80.000000
# 12                         73.622083
# 5                          73.622083
# 5.5                        73.622083
# 6                          70.247500
# 6.5                        80.000000
# 7                          73.622083
# 7.5                        73.622083
# 8                          76.247500
# 8.5                        73.622083
# 9                          73.622083
# 9.5                        70.247500
#
# name  Nike City Trainer Shoe Women's Training Shoes  \
# size
# 10                                        65.000000
# 10.5                                      61.246250
# 11                                        56.875000
# 12                                        65.000000
# 5                                         61.246250
# 5.5                                       61.246250
# 6                                         56.875000
# 6.5                                       59.995000
# 7                                         61.246250
# 7.5                                       58.435000
# 8                                         62.497500
# 8.5                                       65.000000
# 9                                         63.331667
# 9.5                                       59.215000
#
# name  Nike Court Lite Women's Tennis Shoes  \
# size
# 10                                   65.00
# 10.5                                 55.25
# 11                                   65.00
# 12                                   65.00
# 5                                    65.00
# 5.5                                  65.00
# 6                                    65.00
# 6.5                                  65.00
# 7                                    65.00
# 7.5                                  65.00
# 8                                    55.25
# 8.5                                  65.00
# 9                                    65.00
# 9.5                                  65.00
#
# name  Nike Flex Experience 6 Women's Running Shoes  \
# size
# 10                                       60.956667
# 10.5                                     59.337059
# 11                                       60.954412
# 12                                       60.396818
# 5                                        60.087143
# 5.5                                      60.623333
# 6                                        59.864643
# 6.5                                      61.204286
# 7                                        59.720000
# 7.5                                      60.354615
# 8                                        58.865313
# 8.5                                      60.043214
# 9                                        60.802857
# 9.5                                      60.207000
#
# name  Nike Free RN Running Shoe - Women's  \
# size
# 10                                  99.95
# 10.5                                99.95
# 11                                  99.95
# 12                                  99.95
# 5                                   99.95
# 5.5                                 99.95
# 6                                   99.95
# 6.5                                 99.95
# 7                                   99.95
# 7.5                                 99.95
# 8                                   99.95
# 8.5                                 99.95
# 9                                   99.95
# 9.5                                 99.95
#
# name  Nike Initiator Women's Running Shoes  \
# size
# 10                                  52.495
# 10.5                                52.495
# 11                                  55.000
# 12                                  52.495
# 5                                   55.000
# 5.5                                 52.495
# 6                                   52.495
# 6.5                                 52.495
# 7                                   52.495
# 7.5                                 52.495
# 8                                   55.000
# 8.5                                 50.310
# 9                                   52.495
# 9.5                                 50.310
#
# name  Nike Kawa Slide Womens Style : 834588  \
# size
# 10                                  27.4950
# 10.5                                28.7475
# 11                                  28.3300
# 12                                  30.0000
# 5                                   28.7475
# 5.5                                 28.7475
# 6                                   28.7475
# 6.5                                 28.7475
# 7                                   28.3300
# 7.5                                 28.7475
# 8                                   28.9980
# 8.5                                 28.7475
# 9                                   28.7475
# 9.5                                 28.7475
#
# name  Nike LunarEpic Low Flyknit 2 Running Shoe - Women's  \
# size
# 10                                               127.96
# 10.5                                             127.96
# 11                                               127.96
# 12                                               127.96
# 5                                                127.96
# 5.5                                              127.96
# 6                                                127.96
# 6.5                                              127.96
# 7                                                127.96
# 7.5                                              127.96
# 8                                                127.96
# 8.5                                              127.96
# 9                                                127.96
# 9.5                                              127.96
#
# name  Nike LunarGlide 9 Running Shoe - Women's  \
# size
# 10                                     104.955
# 10.5                                   104.955
# 11                                     104.955
# 12                                     104.955
# 5                                      104.955
# 5.5                                    104.955
# 6                                      104.955
# 6.5                                    104.955
# 7                                      104.955
# 7.5                                    104.955
# 8                                      104.955
# 8.5                                    104.955
# 9                                      104.955
# 9.5                                    104.955
#
# name  Nike SB Check Solarsoft Women's Skate Shoes  \
# size
# 10                                         62.495
# 10.5                                       65.000
# 11                                         60.500
# 12                                         62.495
# 5                                          62.495
# 5.5                                        62.495
# 6                                          62.495
# 6.5                                        62.495
# 7                                          62.495
# 7.5                                        59.995
# 8                                          62.495
# 8.5                                        62.495
# 9                                          62.495
# 9.5                                        70.000
#
# name  Nike Superflyte Women's Sneakers  \
# size
# 10                             61.8725
# 10.5                           62.4950
# 11                             62.4950
# 12                             62.4950
# 5                              62.4950
# 5.5                            62.4950
# 6                              62.4950
# 6.5                            62.4950
# 7                              62.4950
# 7.5                            70.0000
# 8                              61.8725
# 8.5                            61.8725
# 9                              62.4950
# 9.5                            70.0000
#
# name  Nike Women's Air Zoom Winflo 4 Running Shoe Anthracite/Dark Grey-Black 10  \
# size
# 10                                            85.498000
# 10.5                                          84.499000
# 11                                            86.523500
# 12                                            85.605429
# 5                                             87.495000
# 5.5                                           85.605429
# 6                                             83.905000
# 6.5                                           81.311250
# 7                                             85.831111
# 7.5                                           90.000000
# 8                                             85.712857
# 8.5                                           84.060000
# 9                                             82.500000
# 9.5                                           85.935625
#
# name  Nike Women's Lunar Apparent Running Shoe  \
# size
# 10                                      77.495
# 10.5                                    77.495
# 11                                      77.495
# 12                                      77.495
# 5                                       77.495
# 5.5                                     77.495
# 6                                       77.495
# 6.5                                     77.495
# 7                                       77.495
# 7.5                                     77.495
# 8                                       77.495
# 8.5                                     77.495
# 9                                       77.495
# 9.5                                     77.495
#
# name  Nike Zoom Janoski Slip-On Skate Shoe - Women's  \
# size
# 10                                            61.835
# 10.5                                          61.835
# 11                                            61.835
# 12                                            61.835
# 5                                             61.835
# 5.5                                           61.835
# 6                                             61.835
# 6.5                                           61.835
# 7                                             61.835
# 7.5                                           61.835
# 8                                             61.835
# 8.5                                           61.835
# 9                                             61.835
# 9.5                                           61.835
#
# name  Women's Nike In-Season 7 Training Shoe Black/Metallic Silver/Anthracite Size 8 M US
# size
# 10                                            69.247000
# 10.5                                          66.499000
# 11                                            68.373000
# 12                                            69.247000
# 5                                             67.968750
# 5.5                                           70.622000
# 6                                             69.581667
# 6.5                                           71.123000
# 7                                             72.030000
# 7.5                                           69.194286
# 8                                             70.248000
# 8.5                                           67.500000
# 9                                             71.248571
# 9.5                                           69.061250

# %%
sns.boxplot(data=nike_size_pivot.transpose())

# %%
woman_shoes['avg_price'].hist()

# %%
sns.distplot([np.sum([woman_shoes['avg_price'].iloc[i] for i in np.random.choice(woman_shoes['avg_price'].shape[0], 100)]) for j in range(10000)],
            bins=25)
